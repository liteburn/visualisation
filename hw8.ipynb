# %%
from IPython.display import Image
Image(filename='data/hw8.png')

# %% [markdown]
# # Недолілки
#
# 1. Нагромадженість графіків( кількість графіків поруч дуже велика, що не дає можливості сфокусуватись на чомусь одному)
# 2. Вертикалькі підписи є вижкими для читання і розуміння
# 3. Також частини структури не є посортованими, що ускладнює розуміння через чередування більших і менших данних
# 4. Важко порівняти окремі параметри між 2010 і 2017 через змішення відносно інших і відносно малі розміри.
